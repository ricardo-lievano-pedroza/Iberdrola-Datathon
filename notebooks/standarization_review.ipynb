# %%
import geopandas as gpd
import pandas as pd 
import polars as pl
import os

# %%
os.getcwd()

# %%
os.chdir('..')

# %%
os.getcwd()

# %%
os.chdir('data/standardized')

# %%
roads_file_name = 'roads.parquet'	
traffic_file_name = 'traffic.parquet'	
chargers_file_name = 'chargers.parquet'	
vehicles_file_name = 'vehicle_registrations.parquet'	
electric_grid_file_name = 'electric_capacity.parquet'	
gas_stations_file_name = 'gas_stations.parquet'

# %%
roads = gpd.read_parquet(roads_file_name)
roads

# %%
traffic = gpd.read_parquet(traffic_file_name)
traffic

# %%
chargers = gpd.read_parquet(chargers_file_name)
chargers

# %%
electric_grid = gpd.read_parquet(electric_grid_file_name)
electric_grid

# %%
len(electric_grid)

# %%
len(electric_grid['row_id'].unique())

# %%
gas_stations = gpd.read_parquet(gas_stations_file_name)
gas_stations

# %%
len(gas_stations)

# %%
vehicles = pl.read_parquet(vehicles_file_name)
vehicles
